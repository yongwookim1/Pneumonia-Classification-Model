# %% [markdown]
# ### Draw graph

# %%
import matplotlib.pyplot as plt
import numpy as np

normal_valid_acc = [0.9492, 0.9636, 0.9703, 0.9722, 0.9722, 0.9732, 0.9751, 0.9732, 0.9722, 0.9732, 0.9712, 0.9732, 0.9751, 0.9741, 0.9741, 0.9732, 0.9722, 0.9732, 0.9732, 0.9751]
clahe_valid_acc = [0.9588, 0.9712, 0.9751, 0.9760, 0.9741, 0.9741, 0.9751, 0.9770, 0.9741, 0.9751, 0.9741, 0.9751, 0.9760, 0.9789, 0.9741, 0.9789, 0.9741, 0.9751, 0.9751, 0.9770]
gs_valid_acc = [0.9396, 0.9655, 0.9636, 0.9674, 0.9741, 0.9722, 0.9732, 0.9703, 0.9732, 0.9741, 0.9741, 0.9741, 0.9760, 0.9741, 0.9732, 0.9732, 0.9712, 0.9722, 0.9732, 0.9751]
normal_valid_loss = [0.1578, 0.0977, 0.0826, 0.0827, 0.0850, 0.0847, 0.0859, 0.0829, 0.0866, 0.0874, 0.0879, 0.0875, 0.0862, 0.0864, 0.0875, 0.0872, 0.0899, 0.0882, 0.0872, 0.0880]
clahe_valid_loss = [0.1285, 0.0854, 0.0718, 0.0695, 0.0727, 0.0693, 0.0698, 0.0717, 0.0742, 0.0729, 0.0734, 0.0717, 0.0706, 0.0701, 0.0714, 0.0697, 0.0743, 0.0718, 0.0708,0.0707]
gs_valid_loss = [0.1664, 0.0971, 0.0839, 0.0854, 0.0867, 0.0860, 0.0888, 0.0874, 0.0862, 0.0902, 0.0902, 0.0899, 0.0898, 0.0889, 0.0888, 0.0893, 0.0922, 0.0895, 0.0885, 0.0911]

f, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 4))
t = f.suptitle('Performance', fontsize=12)
f.subplots_adjust(top=0.85, wspace=0.3)

num_epochs = 20
epoch_list = list(range(1,num_epochs+1))
ax1.plot(epoch_list, normal_valid_acc, label='Normal')
ax1.plot(epoch_list, clahe_valid_acc, label='CLAHE')
ax1.plot(epoch_list, gs_valid_acc, label='GS')
ax1.set_xticks(np.arange(0, num_epochs*2+1, 5))
ax1.set_ylim(0.960, 0.980)
ax1.set_ylabel('Accuracy Value')
ax1.set_xlabel('Epoch')
ax1.set_title('Accuracy')
l1 = ax1.legend(loc="best")

ax2.plot(epoch_list, normal_valid_loss, label='Normal')
ax2.plot(epoch_list, clahe_valid_loss, label='CLAHE')
ax2.plot(epoch_list, gs_valid_loss, label='GS')
ax2.set_xticks(np.arange(0, num_epochs*2+1, 5))
ax2.set_ylim(0.06, 0.110)
ax2.set_ylabel('Loss Value')
ax2.set_xlabel('Epoch')
ax2.set_title('Loss')
l2 = ax2.legend(loc="best")
